# %% [markdown]
# # Домашнее задание 3
#
# Реализуйте:
# 1. **KNNClassifier** - классификатор K-ближайших соседей с нуля
# 2. **PCA** - Principal Component Analysis через eigendecomposition
# 3. **experiment_knn_pca** - эксперимент: accuracy KNN в зависимости от n_components PCA
#
# Проверка: `uv run python -m unittest tests/*.py`

# %%
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris, load_digits, make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA as SkPCA

# %% [markdown]
# ## Часть 1. KNN Classifier с нуля
#
# KNN - алгоритм instance-based learning. "Обучение" сводится к запоминанию всего train set. Основная работа - в `predict`:
#
# 1. Для каждого объекта X_test вычислить расстояния до всех объектов X_train
# 2. Найти K ближайших
# 3. Взять мажоритарный класс среди K соседей
#
# **Подсказки:**
# - Евклидово расстояние: $d(x, y) = \sqrt{\sum_i (x_i - y_i)^2}$
# - Для эффективного поиска K ближайших используйте `np.argpartition` (O(n)) вместо `np.argsort` (O(n log n))
# - Мажоритарное голосование: `np.bincount` + `np.argmax`

# %%
class KNNClassifier:
    def __init__(self, n_neighbors=5):
        """
        Parameters
        ----------
        n_neighbors : int
            Number of neighbors to use for classification.
        """
        self.n_neighbors = n_neighbors

    def fit(self, X, y):
        """
        "Training" is just memorizing the data.

        Store:
        - self.X_train_ : np.array of shape (n_samples, n_features)
        - self.y_train_ : np.array of shape (n_samples,)
        - self.classes_ : np.array of unique class labels

        Returns self (for chaining).
        """
        # TODO: implement
        pass

    def predict(self, X):
        """
        For each sample in X:
          1. Compute Euclidean distances to all training samples.
          2. Find indices of n_neighbors smallest distances.
          3. Return the most frequent class among those neighbors.

        Hints:
        - Compute all pairwise distances at once using broadcasting:
          `dists = np.sqrt(((X[:, None, :] - X_train[None, :, :]) ** 2).sum(axis=2))`
          This gives shape (n_test, n_train).
        - For finding K nearest: np.argpartition(dists, K, axis=1)[:, :K]
          is faster than argsort and sufficient (we don't need them sorted).
        - Majority vote: np.bincount(neighbor_labels).argmax()

        Returns
        -------
        np.array of shape (n_samples,)
        """
        # TODO: implement
        pass

# %% [markdown]
# ### Проверка KNN

# %%
if __name__ != "homework":
    # Простые 2D данные для визуализации
    X_vis, y_vis = make_classification(
        n_samples=200, n_features=2, n_informative=2, n_redundant=0,
        n_classes=3, n_clusters_per_class=1, random_state=42,
    )
    X_vis_tr, X_vis_te, y_vis_tr, y_vis_te = train_test_split(
        X_vis, y_vis, test_size=0.3, random_state=42,
    )

# %%
if __name__ != "homework":
    # Сравнение разных K
    from matplotlib.colors import ListedColormap
    cmap_bg = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])

    fig, axes = plt.subplots(1, 4, figsize=(22, 5))
    for ax, k in zip(axes, [1, 5, 15, 50]):
        clf = KNNClassifier(n_neighbors=k).fit(X_vis_tr, y_vis_tr)
        
        # Decision boundary
        eps = 0.5
        xx, yy = np.meshgrid(
            np.linspace(X_vis[:, 0].min() - eps, X_vis[:, 0].max() + eps, 200),
            np.linspace(X_vis[:, 1].min() - eps, X_vis[:, 1].max() + eps, 200),
        )
        Z = clf.predict(np.c_[xx.ravel(), yy.ravel()]).reshape(xx.shape)
        ax.pcolormesh(xx, yy, Z, cmap=cmap_bg, alpha=0.4)
        ax.scatter(X_vis_te[:, 0], X_vis_te[:, 1], c=y_vis_te, cmap='brg', edgecolors='k', s=25)
        
        acc = accuracy_score(y_vis_te, clf.predict(X_vis_te))
        ax.set_title(f'K={k}, test acc={acc:.3f}')
        ax.grid(alpha=0.2)
    plt.suptitle('KNN decision boundary: эффект K', fontsize=14)
    plt.tight_layout()
    plt.show()

# %%
if __name__ != "homework":
    # Сравнение с sklearn на Iris
    iris = load_iris()
    X_ir_tr, X_ir_te, y_ir_tr, y_ir_te = train_test_split(
        iris.data, iris.target, test_size=0.3, random_state=42,
    )

    our = KNNClassifier(n_neighbors=5).fit(X_ir_tr, y_ir_tr)
    sk = KNeighborsClassifier(n_neighbors=5).fit(X_ir_tr, y_ir_tr)

    print(f'Our KNN:     {accuracy_score(y_ir_te, our.predict(X_ir_te)):.4f}')
    print(f'sklearn KNN: {accuracy_score(y_ir_te, sk.predict(X_ir_te)):.4f}')

# %% [markdown]
# ## Часть 2. PCA с нуля (eigendecomposition)
#
# PCA находит направления максимальной дисперсии. Алгоритм:
#
# 1. **Центрирование**: вычесть среднее по каждому признаку
# 2. **Ковариационная матрица**: $C = \frac{1}{n-1} X_c^T X_c$
# 3. **Eigendecomposition**: найти собственные значения и векторы матрицы $C$
# 4. **Сортировка**: отсортировать по убыванию собственных значений
# 5. **Выбор**: взять первые `n_components` собственных векторов
#
# **Подсказки:**
# - `np.linalg.eigh(C)` для симметричной матрицы (ковариация всегда симметрична) - возвращает собственные значения **в возрастающем порядке**
# - Чтобы развернуть: `[::-1]` для значений и соответствующая перестановка столбцов для векторов
# - `components_` - матрица (n_components, n_features), где каждая строка - собственный вектор
# - `transform(X)`: $X_{new} = (X - \bar{X}) \cdot W^T$, где $W$ = `components_`
# - `inverse_transform(X_new)`: $X \approx X_{new} \cdot W + \bar{X}$

# %%
class PCA:
    def __init__(self, n_components):
        """
        Parameters
        ----------
        n_components : int
            Number of components to keep.
        """
        self.n_components = n_components

    def fit(self, X):
        """
        Fit PCA via eigendecomposition of the covariance matrix.

        Steps:
        1. Compute mean: self.mean_ = X.mean(axis=0)
        2. Center data: X_centered = X - self.mean_
        3. Covariance matrix: C = (X_centered.T @ X_centered) / (n - 1)
           (Note: np.cov(X, rowvar=False) does the same, but computing manually
           is a good exercise)
        4. Eigendecomposition: eigenvalues, eigenvectors = np.linalg.eigh(C)
           IMPORTANT: eigh returns eigenvalues in ASCENDING order.
           You must reverse them and the corresponding eigenvectors.
        5. Select top n_components.

        Store:
        - self.mean_ : np.array of shape (n_features,)
        - self.components_ : np.array of shape (n_components, n_features)
          Each row is a principal component (eigenvector).
        - self.explained_variance_ : np.array of shape (n_components,)
          Eigenvalues (= variance along each component).
        - self.explained_variance_ratio_ : np.array of shape (n_components,)
          explained_variance_ / total_variance

        Returns self.
        """
        # TODO: implement
        pass

    def transform(self, X):
        """
        Project X onto the principal components.

        Formula: X_new = (X - mean_) @ components_.T

        Returns
        -------
        np.array of shape (n_samples, n_components)
        """
        # TODO: implement
        pass

    def inverse_transform(self, X_new):
        """
        Transform back from principal components to original space.

        Formula: X_restored = X_new @ components_ + mean_

        Note: this is exact only if n_components == n_features.
        Otherwise it's an approximation (information lost during dim reduction).

        Returns
        -------
        np.array of shape (n_samples, n_features)
        """
        # TODO: implement
        pass

    def fit_transform(self, X):
        """Convenience method: fit then transform."""
        return self.fit(X).transform(X)

# %% [markdown]
# ### Проверка PCA

# %%
if __name__ != "homework":
    # Визуализация PCA на Iris
    iris = load_iris()
    X_iris = iris.data
    y_iris = iris.target

    our_pca = PCA(n_components=2).fit(X_iris)
    X_our = our_pca.transform(X_iris)

    sk_pca = SkPCA(n_components=2).fit(X_iris)
    X_sk = sk_pca.transform(X_iris)

    fig, axes = plt.subplots(1, 2, figsize=(14, 6))
    for cls in np.unique(y_iris):
        mask = y_iris == cls
        axes[0].scatter(X_our[mask, 0], X_our[mask, 1], label=iris.target_names[cls], s=30)
        axes[1].scatter(X_sk[mask, 0], X_sk[mask, 1], label=iris.target_names[cls], s=30)

    axes[0].set_title(f'Our PCA (explained variance: {our_pca.explained_variance_ratio_.sum():.2%})')
    axes[1].set_title(f'sklearn PCA (explained variance: {sk_pca.explained_variance_ratio_.sum():.2%})')
    for ax in axes:
        ax.set_xlabel('PC1')
        ax.set_ylabel('PC2')
        ax.legend()
        ax.grid(alpha=0.2)
    plt.suptitle('Iris: 4D -> 2D через PCA', fontsize=14)
    plt.tight_layout()
    plt.show()

    # Примечание: наши компоненты могут отличаться знаком от sklearn - это норма.

# %%
if __name__ != "homework":
    # Scree plot: доля дисперсии каждой компоненты
    digits = load_digits()
    pca_full = PCA(n_components=digits.data.shape[1]).fit(digits.data)

    plt.figure(figsize=(12, 5))
    plt.bar(range(1, len(pca_full.explained_variance_ratio_) + 1),
            pca_full.explained_variance_ratio_, alpha=0.7, label='Individual')
    plt.plot(range(1, len(pca_full.explained_variance_ratio_) + 1),
             np.cumsum(pca_full.explained_variance_ratio_), 'ro-', label='Cumulative')
    plt.axhline(y=0.95, color='g', linestyle='--', alpha=0.5, label='95% threshold')
    plt.xlabel('Component')
    plt.ylabel('Explained variance ratio')
    plt.title('Scree plot (digits, 64 features)')
    plt.legend()
    plt.grid(True, axis='y')
    plt.show()

    n_for_95 = np.argmax(np.cumsum(pca_full.explained_variance_ratio_) >= 0.95) + 1
    print(f'Для 95% дисперсии нужно {n_for_95} компонент (из 64)')

# %% [markdown]
# ## Часть 3. Эксперимент: KNN + PCA
#
# Исследуем, как точность KNN зависит от размерности признакового пространства. KNN страдает от curse of dimensionality: в высоких размерностях расстояния "сплющиваются" и соседи становятся неинформативными.
#
# Гипотеза: PCA-проекция может помочь (убирая шумные измерения), но только до определенного момента - слишком сильное сжатие удаляет полезную информацию.

# %%
def experiment_knn_pca(X, y, n_components_list, k=5, test_size=0.3, random_state=42):
    """
    Run KNN after PCA dimensionality reduction for various n_components.

    Steps:
    1. Split X, y into train/test (use train_test_split with given random_state).
    2. For each n_components in n_components_list:
       a. Fit YOUR PCA on X_train.
       b. Transform both X_train and X_test.
       c. Fit YOUR KNNClassifier on the reduced train set.
       d. Compute accuracy on the reduced test set.
    3. Return a dict with the results.

    Parameters
    ----------
    X, y : full dataset
    n_components_list : list of int
        Values of n_components to try.
    k : int
        Number of neighbors for KNN.

    Returns
    -------
    dict with keys:
        'n_components' : list of n_components values (same as input)
        'accuracies'   : list of test accuracies, one per n_components
    """
    # TODO: implement
    pass

# %% [markdown]
# ### Проверка эксперимента

# %%
if __name__ != "homework":
    # Digits: 64 признака, 10 классов
    digits = load_digits()
    n_components_list = [1, 2, 5, 10, 20, 30, 40, 50, 64]
    results = experiment_knn_pca(digits.data, digits.target, n_components_list, k=5)

    # Сравним с baseline: KNN на исходных данных (= n_components = 64 в нашем случае)
    plt.figure(figsize=(12, 6))
    plt.plot(results['n_components'], results['accuracies'], 'o-', linewidth=2, markersize=10, label='KNN + PCA')
    
    # Baseline: прямое применение KNN
    X_tr, X_te, y_tr, y_te = train_test_split(digits.data, digits.target, test_size=0.3, random_state=42)
    baseline_acc = accuracy_score(y_te, KNNClassifier(n_neighbors=5).fit(X_tr, y_tr).predict(X_te))
    plt.axhline(y=baseline_acc, color='r', linestyle='--', label=f'Baseline (no PCA): {baseline_acc:.3f}')

    plt.xlabel('n_components')
    plt.ylabel('Test accuracy')
    plt.title('KNN accuracy vs PCA dimensionality (digits, K=5)')
    plt.legend()
    plt.grid(True)
    plt.show()

    # Лучший результат
    best_idx = int(np.argmax(results['accuracies']))
    print(f"Best: n_components={results['n_components'][best_idx]}, "
          f"accuracy={results['accuracies'][best_idx]:.4f}")
    print(f"Baseline (no PCA): {baseline_acc:.4f}")
